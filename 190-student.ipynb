# %%
print("Name : ")

# %%
#import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
bmi_df = pd.read_csv('bmi.csv')
bmi_df
#Task 1
#Read the bmi.csv
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           177            0      129            110             46      130
# 1           445            0      180             78             63       14
# 2           673            3      123            100             35      240
# 3           125            1       88             30             42       99
# 4           120            0      162             76             56      100
# ..          ...          ...      ...            ...            ...      ...
# 763         426            0       94              0              0        0
# 764         706           10      115              0              0        0
# 765         371            0      118             64             23       89
# 766           9            8      125             96              0        0
# 767         145            0      102             75             23        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    67.1                     0.319   26        1
# 1    59.4                     2.420   25        1
# 2    57.3                     0.880   22        0
# 3    55.0                     0.496   26        1
# 4    53.2                     0.759   25        1
# ..    ...                       ...  ...      ...
# 763   0.0                     0.256   25        0
# 764   0.0                     0.261   30        1
# 765   0.0                     1.731   21        0
# 766   0.0                     0.232   54        1
# 767   0.0                     0.572   21        0
#
# [768 rows x 10 columns]

# %%
#Task 2
top_5 = bmi_df.head(5)
name = top_5['Age']
number = top_5['BMI']

plt.xlabel("Age")
plt.xticks(rotation='vertical')
plt.ylabel("BMI")
label = name
value = number
plt.bar(label, value,width=0.5, color=('blue','purple','orange','pink','red'))

#Data is sorted in descending order in accordance with BMI value
#Find the top 5 age group where the BMI value is the highest, and plot a bar graph out of it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Task 2
# ----> 2 top_5 = bmi_df.head(5)
#       3 name = top_5['Age']
#       4 number = top_5['BMI']
#
# NameError: name 'bmi_df' is not defined

# %%
#Task 3
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
bp_df = pd.read_csv("blood_pressure.csv")
bp_df


#Read blood_pressure.csv
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           347            3      116              0              0        0
# 1           494            3       80              0              0        0
# 2           222            7      119              0              0        0
# 3            81            2       74              0              0        0
# 4            78            0      131              0              0        0
# ..          ...          ...      ...            ...            ...      ...
# 763         549            4      189            110             31        0
# 764          43            9      171            110             24      240
# 765         177            0      129            110             46      130
# 766         691           13      158            114              0        0
# 767         106            1       96            122              0        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    23.5                     0.187   23        0
# 1     0.0                     0.174   22        0
# 2    25.2                     0.209   37        0
# 3     0.0                     0.102   22        0
# 4    43.2                     0.270   26        1
# ..    ...                       ...  ...      ...
# 763  28.5                     0.680   37        0
# 764  45.4                     0.721   54        1
# 765  67.1                     0.319   26        1
# 766  42.3                     0.257   44        1
# 767  22.4                     0.207   27        0
#
# [768 rows x 10 columns]

# %%
#Task 4
bottom_5 = bp_df.head(5)
name = bottom_5['Age']
number = bottom_5['BMI']

plt.xlabel("Age")
plt.xticks(rotation='vertical')
plt.ylabel("Blood Pressure")
label = name
value = number
plt.bar(label, value,width=0.5, color=('blue','pink','orange','purple','red'))
#Data is sorted in ascending order in accordance with Blood Pressure
#Find the top 5 age group where the BloodPressure value is the highest, and plot a bar graph out of it
# Out:
# <BarContainer object of 5 artists>

# %%
#Task 5
#Read the insulin.csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
insulin_df = pd.read_csv("insulin.csv")
insulin_df
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            13            1      189             60             23      846
# 1           228            4      197             70             39      744
# 2           247            0      165             90             33      680
# 3           584            8      124             76             24      600
# 4           409            1      172             68             49      579
# ..          ...          ...      ...            ...            ...      ...
# 763         218            5       85             74             22        0
# 764           5            5      116             74              0        0
# 765         598            1      173             74              0        0
# 766         761            9      170             74             31        0
# 767         266            0      138              0              0        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    30.1                     0.398   59        1
# 1    36.7                     2.329   31        0
# 2    52.3                     0.427   23        0
# 3    28.7                     0.687   52        1
# 4    42.4                     0.702   28        1
# ..    ...                       ...  ...      ...
# 763  29.0                     1.224   32        1
# 764  25.6                     0.201   30        0
# 765  36.8                     0.088   38        1
# 766  44.0                     0.403   43        1
# 767  36.3                     0.933   25        1
#
# [768 rows x 10 columns]

# %%
#Task 6
top_1 = insulin_df.head(1)
name = top_1['Glucose']
number = top_1['BMI']

plt.xlabel("When Insulin is the highest Glucose is:")

plt.ylabel("When Insulin is the highest BMI value is:")
label = name
value = number
plt.bar(label, value,width=0.5, color=('blue','pink','orange','purple','red'))
#Data is sorted in descending order in accordance with Insulin value
#Find out what will be the Glucose and BMI value when the Insulin is highest
# Out:
# <BarContainer object of 1 artists>
